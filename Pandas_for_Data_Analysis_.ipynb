# %% [markdown]
# ![pandas.PNG](data:image/png;base64,...)

# %% [markdown]
# ![pandas1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![pandas2.PNG](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Two main Datatypes
series=pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series=1-dimensional

# %%
colours=pd.Series(["Red","Blue","White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame=2-dimensional
# DataFrame uses python Dictionaries
car_data=pd.DataFrame({"Car make":series,"Colours":colours})
car_data
# Out:
#   Car make Colours
# 0      BMW     Red
# 1   Toyota    Blue
# 2    Honda   White

# %%
# Import Data
# Export data as Coma separated value(csv)
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ![pandas3.PNG](data:image/png;base64,...)

# %%
# Exporting a dataframe
# if we donot define index it will copy the first column
car_sales.to_csv("exported-car-sales.csv",index=False)

# %%
# Reimport the File
exported_car_sales=pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
# Attribute
# tell about the datatype of columns of DataFrame
car_sales.dtypes
# function
#car_sale.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# return as a list
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Function have bracket
car_sales.describe()
# counts =Number of columns
# Why we Donot have Price Column
# Because dtype of Price Column is Object
# Describe work on only Numeric Column
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_price=pd.Series([3000,1500,111250])
car_price.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
# To selects a Specific Column we use Square Brackets
car_sales["Doors"]
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales
    )
# Out:
# 10

# %% [markdown]
# ## Viewing and Selecting Data

# %%
# Return the Top 5 Row of data
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# bottom 5 rows
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc and iloc
#.loc ==Location
animal=pd.Series(["cat","dog", "bird","panda","snake"],index=[0,3,9,8,3])
animal
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
#Get the thing at location 3
animal.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animal.loc[9]
# Out:
# 'bird'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animal
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .iloc refers to Position
animal.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animal
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# Slicing
animal.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
# upto and including 3
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
# Make Colum
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# Dot would work if Column name have a Space in Name 
# Try  car_sales.Odometer (KM) it Will Give Error
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Bollon Indexing
# I only want a car that is Toyota
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Compare Columns
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()

# %%
# Histogram
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].dtype
# car_sales["price"].hist() # would work as it is datatype Object
# Out:
# dtype('O')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Keep the values the Same and access the String and replace them with nothing and store it as int
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales.Price.plot()

# %% [markdown]
# ## Manipulating Data

# %%
# Reassignment
car_sales["Make"]=car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
# in real Life some of the data in Dataset is Missing
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
# We want to Fill Not avalable values with mean values 
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),
                                                                   inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# SomeTime We have to Drop NA values
# inplace =Trues Instantly save the result
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped=car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sale-missing-dropped.csv")

# %%
# Create a data within Exsisting Data
# Columns From Series
seat_columns=pd.Series([5,5,5,5,5])
seat_columns
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
#New Columns Called Seats
car_sales["Seats"]=seat_columns
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales.fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
# Create a Column From Python List 
# List Size should be same as the size of column already in dataFrame other wise Error
fuel_economy=[7.5,9.2,5.0,9.6,8.7,4.7,7.6,8.7,3.0,4.5]
car_sales["Fuel per 100KM"]=fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5

# %%
car_sales["Total fuel  used"]=car_sales["Odometer (KM)"]/100 *car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  ...  Seats  Fuel per 100KM  Total fuel  used
# 0  toyota  White         150043  ...    5.0             7.5         11253.225
# 1   honda    Red          87899  ...    5.0             9.2          8086.708
# 2  toyota   Blue          32549  ...    5.0             5.0          1627.450
# 3     bmw  Black          11179  ...    5.0             9.6          1073.184
# 4  nissan  White         213095  ...    5.0             8.7         18539.265
# 5  toyota  Green          99213  ...    5.0             4.7          4663.011
# 6   honda   Blue          45698  ...    5.0             7.6          3473.048
# 7   honda   Blue          54738  ...    5.0             8.7          4762.206
# 8  toyota  White          60000  ...    5.0             3.0          1800.000
# 9  nissan  White          31600  ...    5.0             4.5          1422.000
#
# [10 rows x 8 columns]

# %%
# Create a Column From Single value
car_sales["Number of Wheels"]=4
car_sales
# Out:
#      Make Colour  ...  Total fuel  used  Number of Wheels
# 0  toyota  White  ...         11253.225                 4
# 1   honda    Red  ...          8086.708                 4
# 2  toyota   Blue  ...          1627.450                 4
# 3     bmw  Black  ...          1073.184                 4
# 4  nissan  White  ...         18539.265                 4
# 5  toyota  Green  ...          4663.011                 4
# 6   honda   Blue  ...          3473.048                 4
# 7   honda   Blue  ...          4762.206                 4
# 8  toyota  White  ...          1800.000                 4
# 9  nissan  White  ...          1422.000                 4
#
# [10 rows x 9 columns]

# %%
car_sales["Passed road saftey"]=True
car_sales
# Out:
#      Make Colour  ...  Number of Wheels  Passed road saftey
# 0  toyota  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 4  nissan  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 8  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
#
# [10 rows x 10 columns]

# %%
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int64
# Seats                 float64
# Fuel per 100KM        float64
# Total fuel  used      float64
# Number of Wheels        int64
# Passed road saftey       bool
# dtype: object

# %%
car_sales["Total Fuel used (L)"]=car_sales["Total fuel  used"]
car_sales
# Out:
#      Make Colour  ...  Passed road saftey  Total Fuel used (L)
# 0  toyota  White  ...                True            11253.225
# 1   honda    Red  ...                True             8086.708
# 2  toyota   Blue  ...                True             1627.450
# 3     bmw  Black  ...                True             1073.184
# 4  nissan  White  ...                True            18539.265
# 5  toyota  Green  ...                True             4663.011
# 6   honda   Blue  ...                True             3473.048
# 7   honda   Blue  ...                True             4762.206
# 8  toyota  White  ...                True             1800.000
# 9  nissan  White  ...                True             1422.000
#
# [10 rows x 11 columns]

# %%
car_sales=car_sales.drop("Total Fuel used (L)",axis=1)

# %%
car_sales
# Out:
#      Make Colour  ...  Number of Wheels  Passed road saftey
# 0  toyota  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 4  nissan  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 8  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
#
# [10 rows x 10 columns]

# %%
# Get a Sample from 100 of the Data
# Data will Shuffle
car_sales_shuffled=car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  ...  Number of Wheels  Passed road saftey
# 4  nissan  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 0  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
# 8  toyota  White  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 5  toyota  Green  ...                 4                True
#
# [10 rows x 10 columns]

# %%
# Only Select 20% of the Data
car_sales_shuffled.sample(frac=0.01)
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price, Seats, Fuel per 100KM, Total fuel  used, Number of Wheels, Passed road saftey]
# Index: []

# %%
car_sales_shuffled
# Out:
#      Make Colour  ...  Number of Wheels  Passed road saftey
# 4  nissan  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 0  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
# 8  toyota  White  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 5  toyota  Green  ...                 4                True
#
# [10 rows x 10 columns]

# %%
# we have to reset the index
# If we donot give the paramenter in reset index it will insert the new column of idex at start
car_sales_shuffled.reset_index(inplace=True,drop=True)

# %%
# Drop will drop the shuffled idex column
car_sales_shuffled
# Out:
#      Make Colour  ...  Number of Wheels  Passed road saftey
# 0  nissan  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 2     bmw  Black  ...                 4                True
# 3   honda   Blue  ...                 4                True
# 4  toyota   Blue  ...                 4                True
# 5  toyota  White  ...                 4                True
# 6  nissan  White  ...                 4                True
# 7  toyota  White  ...                 4                True
# 8   honda   Blue  ...                 4                True
# 9  toyota  Green  ...                 4                True
#
# [10 rows x 10 columns]

# %%
# apply is a way to assign a function to column
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  ...  Number of Wheels  Passed road saftey
# 0  toyota  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 4  nissan  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 8  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
#
# [10 rows x 10 columns]
